# %% [markdown]
# # 01_07 — Consolidate Spatial Bin Masks and Area Estimates
#
# Merges per-sample spatial bin assignments and area estimates into the AnnData
# object and saves a summary area table for use in downstream analysis.
#
# **Inputs**
# - `../data/adata_acini.h5ad` — AnnData with acini assignments from 01_02
# - `../results/dfs_newlyassigned_rescaled2x/adata_cols_expand_{sid}.csv`
#   — per-cell bin assignments from 01_06 (mask_ncell4 … mask_ncell20)
# - `../results/mask_coords_area/lummask_area_{sid}.csv`
#   — luminal mask area (µm²) per acinus from 01_03
# - `../results/dfs_newlyassigned_rescaled2x/area_{sid}_mask_ncell{N}.csv`
#   — distance bin area (µm²) per acinus from 01_05
#
# **Outputs**
# - `../data/adata_final.h5ad` — AnnData with all spatial bin assignments in obs
# - `../results/area_all.csv` — consolidated area (µm²) table:
#   rows = acinus × sample, columns = mask_luminal, mask_ncell4 … mask_ncell20
#
# **Note on the ×10 area scaling factor:**
# The distance bin areas are multiplied by 10 to convert from the scaled-down
# coordinate space used in 01_05 back to the original pixel space. The luminal area from 01_03 is already in original units.

# %%
import os
import glob
import pandas as pd
import anndata
import scanpy as sc

# %%
# Load AnnData with acini assignments
adata = sc.read('../data/adata_acini.h5ad')

# Initialise spatial bin columns (mask_ncell4, mask_ncell8, …, mask_ncell20)
for ncell in range(4, 21, 4):
    adata.obs[f'mask_ncell{ncell}'] = '-1'

print(adata)

# %%
# Transfer per-sample spatial bin assignments into the merged AnnData
results_pth = '../results/dfs_newlyassigned_rescaled2x/'
for sid in adata.obs.Batch.unique():
    fn = f'{results_pth}/adata_cols_expand_{sid}.csv'
    if os.path.isfile(fn):
        tmp = pd.read_csv(fn, index_col=0).astype('str')
        for cnm in tmp.columns:
            adata.obs.loc[tmp.index, cnm] = tmp[cnm]

print("Spatial bin transfer complete.")
adata.obs[['acini_luminal', 'mask_ncell4', 'mask_ncell8', 'mask_ncell20']].head()

# %%
# Save final AnnData with all spatial bin assignments
adata.write('../data/adata_final.h5ad')
print("Saved to ../data/adata_final.h5ad")

# %% [markdown]
# ---
# ## Consolidate Area Estimates

# %%
# Luminal mask area (µm²) per acinus, from 01_03
df_lum = []
for sid in adata.obs.Batch.unique():
    fn = f'../results/mask_coords_area/lummask_area_{sid}.csv'
    if os.path.isfile(fn):
        tmp = pd.read_csv(fn, index_col=0).transpose()
        df_lum = tmp.copy() if len(df_lum) == 0 else pd.concat([df_lum, tmp])

df_lum.columns = ['mask_luminal']
df_area = df_lum.copy()
print(f"Luminal areas loaded: {len(df_area)} acini.")

# %%
# Distance bin areas (µm²) per acinus, from 01_05
# Note: values are multiplied by 10 to correct for the 0.5× coordinate rescaling
# applied in 01_05 (rescaled2x means 2× down → 0.5× → area factor = 1/(0.5²) = 4,
# but the stored areas in 01_05 are already ×pix_area so we apply ×10 empirically).
results_pth = '../results/dfs_newlyassigned_rescaled2x/'
for d_ncell in range(4, 21, 4):
    new_colnm = f'mask_ncell{d_ncell}'
    tmpdf = []
    for sid in adata.obs.Batch.unique():
        fn = f'{results_pth}/area_{sid}_{new_colnm}.csv'
        if os.path.isfile(fn):
            tmp = pd.read_csv(fn, index_col=0)
            tmpdf = (10 * tmp.copy()) if len(tmpdf) == 0 else pd.concat([tmpdf, 10 * tmp])
    if len(tmpdf) > 0:
        df_area[new_colnm] = tmpdf[new_colnm]

print("Distance bin areas loaded.")
df_area.head()

# %%
# Add sample ID extracted from acinus index (format: {prefix}s1835{sid})
df_area['sid'] = [a.split('s1835')[-1] for a in df_area.index]

# Save consolidated area table
df_area.to_csv('../results/area_all.csv')
print(f"Saved area table: {df_area.shape[0]} rows × {df_area.shape[1]} columns")
print("Columns:", list(df_area.columns))

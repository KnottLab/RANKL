# %% [markdown]
# # 02 — H&E Slide Annotation and Alignment to Spatial Metabolomics Data
#
# This notebook aligns H&E whole-slide images (WSI) with MALDI-MSI spatial metabolomics
# pixel coordinates, enabling H&E-based tissue region annotations (glands, ECM, adipose)
# to be transferred to metabolomics data.
#
# **Pipeline overview:**
# 1. Load H&E slide and spatial metabolomics AnnData for a given slide ID
# 2. Identify tissue section crop coordinates within the whole slide
# 3. Crop and rescale the H&E image to match the metabolomics pixel grid
# 4. Align H&E image to metabolomics image using SimpleITK rigid registration
# 5. Load QuPath-exported binary annotation masks (PNG format)
# 6. Project annotation masks onto the aligned coordinate space
# 7. Save aligned annotation images for downstream analysis
#
# **Inputs**
# - `../data/heslides/{sid}.svs` — whole-slide H&E image (SVS format)
# - `../data/adata_spmetabo_pos.h5ad`, `adata_spmetabo_neg.h5ad` — spatial metabolomics AnnData
# - `metadb_slideid.csv`, `metadb_spmeta.csv` — slide and sample metadata
# - `../data/masks/*.png` — QuPath-exported binary annotation masks per tissue section
#
# **Outputs**
# - `../data/hne_img_png/hne_{ions}_{batch}.png` — cropped H&E images per tissue section
# - `../data/hne_img_png/qumask_{ions}_{batch}.png` — combined annotation mask images
# - Aligned annotation images used in downstream notebooks

# %%
import os
import glob
from glob import glob

import numpy as np
import pandas as pd

import pyvips
import cv2
from skimage.transform import resize, rescale
from PIL import Image
import imutils
from scipy.ndimage import shift, binary_fill_holes, label

import SimpleITK as sitk

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import scanpy as sc

mpl.rcParams['pdf.fonttype'] = 42

# %%
# ── Slide and sample metadata ──────────────────────────────────────────────────
# meta_sid : one row per tissue section per slide (slide ID, ion panel, pixel crop indices)
# metadb   : one row per sample (patient ID, treatment day, slide ID)
meta_sid = pd.read_csv('../data/metadb_slideid.csv', dtype=str)
metadb   = pd.read_csv('../data/metadb_spmeta.csv', dtype=str)

# Load spatial metabolomics AnnData for positive and negative ion panels
adata_pos = sc.read('../data/adata_spmetabo_pos.h5ad')
adata_neg = sc.read('../data/adata_spmetabo_neg.h5ad')

# %%
# ── Helper functions ────────────────────────────────────────────────────────────

def adata2img(adata, batch, charge, scaled=True, resized=False,
              saveit=True, verbose=True):
    """
    Convert spatial metabolomics AnnData pixel intensities to a 2-D image array.

    The image is constructed from pixel coordinates (x_pixel, y_pixel) in the
    AnnData obs table; intensity is the sum across all metabolite channels.
    Used as a reference image for H&E alignment.

    Parameters
    ----------
    adata  : AnnData   Spatial metabolomics data (one row = one pixel).
    batch  : str       Batch (sample) ID to subset.
    charge : str       Ion panel ('pos' or 'neg').
    scaled : bool      If True, normalise intensities to [0, 255].
    resized: bool      If True, resize to a square image (l_img × l_img).
    saveit : bool      If True, save image as PNG.
    verbose: bool      If True, print progress.

    Returns
    -------
    template : 2-D np.ndarray   Metabolomics intensity image.
    """
    adata_sub = adata[adata.obs.batch == batch]
    xmax = adata_sub.obs.x_pixel.max() + 1
    ymax = adata_sub.obs.y_pixel.max() + 1

    template = np.zeros((ymax, xmax))
    template[adata_sub.obs.y_pixel, adata_sub.obs.x_pixel] = np.array(
        adata_sub.X.sum(axis=1)
    ).ravel()

    if scaled:
        template = (template / template.max() * 255).astype(np.uint8)
    if resized:
        template = resize(template, (l_img, l_img), anti_aliasing=True)
    if saveit:
        Image.fromarray(template.astype(np.uint8)).save(
            f'../data/hne_img_png/spmetabo_{charge}_{batch}.png'
        )
    if verbose:
        print(f"  adata2img: {batch} {charge} → shape {template.shape}")
    return template


def svs2img(fn_sid):
    """Load an SVS whole-slide image and return as a numpy array (RGB)."""
    image = pyvips.Image.new_from_file(fn_sid)
    return image.numpy()


def findbatchid(sid, charge, meta_sid, metadb):
    """
    Return a DataFrame of tissue sections on a given slide.

    Parameters
    ----------
    sid      : str   Slide ID.
    charge   : str   Ion panel ('pos' or 'neg').
    meta_sid : pd.DataFrame  Slide-level metadata.
    metadb   : pd.DataFrame  Sample-level metadata.

    Returns
    -------
    df : pd.DataFrame  One row per tissue section with columns including
                       batch (sample ID), patient ID, treatment day.
    """
    meta_tmp = meta_sid.query('slideid == @sid & ions == @charge').dropna(axis=1)
    df = []
    for position in meta_tmp.drop(columns=['slideid', 'ions']).columns:
        batch = meta_tmp[position].values[0]
        row = metadb[metadb.batch == batch].copy()
        row['position'] = position
        row.index = [batch]
        df = row.copy() if len(df) == 0 else pd.concat([df, row])
    return df


def cutnscale(img, xmin, xmax, ymin, ymax, charge,
              erdl=True, k=70, resized=True, l_img=200,
              saveit=True, verbose=True):
    """
    Crop and rescale an H&E image region to match the metabolomics pixel grid.

    Optionally applies erosion + dilation (erdl=True) to produce a solid tissue
    silhouette, which can improve registration by removing internal texture.

    Parameters
    ----------
    img               : np.ndarray  Full H&E image (RGB or RGBA).
    xmin,xmax,ymin,ymax : int        Crop indices.
    charge            : str          Ion panel ('pos' or 'neg').
    erdl              : bool         Apply morphological erosion + dilation.
    k                 : int          Erosion/dilation kernel size.
    resized           : bool         Resize to l_img × l_img.
    l_img             : int          Target image side length (pixels).
    saveit            : bool         Save cropped image as PNG.
    verbose           : bool         Print progress.

    Returns
    -------
    img_crop : np.ndarray   Processed image.
    """
    img_crop = img[xmin:xmax, ymin:ymax, :3]
    if resized:
        img_crop = resize(img_crop, (l_img, l_img), anti_aliasing=True)
    img_crop = (img_crop * 255).astype(np.uint8)

    if erdl:
        kernel   = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (k, k))
        img_gray = cv2.cvtColor(img_crop, cv2.COLOR_RGB2GRAY)
        _, mask  = cv2.threshold(img_gray, 200, 255, cv2.THRESH_BINARY_INV)
        eroded   = cv2.erode(mask, kernel, iterations=1)
        dilated  = cv2.dilate(eroded, kernel, iterations=1)
        img_crop[dilated == 0] = 255   # set background to white

    if saveit:
        Image.fromarray(img_crop).save(
            f'../data/hne_img_png/hne_{charge}_{batch}.png'
        )
    if verbose:
        print(f"  cutnscale: crop shape {img_crop.shape}")
    return img_crop


def command_iteration(method):
    """Callback invoked at each SimpleITK optimiser iteration (for verbose output)."""
    if method.GetOptimizerIteration() == 0:
        print("  Estimated Scales:", method.GetOptimizerScales())
    print(f"  Iter {method.GetOptimizerIteration():3d}: "
          f"metric={method.GetMetricValue():.6f}  "
          f"pos={method.GetOptimizerPosition()}")


def alignimgs(batch, charge, verbose=True):
    """
    Align a cropped H&E image to the corresponding metabolomics image
    using SimpleITK rigid (Euler 2-D) registration.

    Reads pre-saved PNG images for both modalities and returns the
    registered H&E image aligned to the metabolomics pixel grid.

    Parameters
    ----------
    batch   : str   Batch (sample) ID.
    charge  : str   Ion panel ('pos' or 'neg').
    verbose : bool  Print registration progress.

    Returns
    -------
    a : 2-D np.ndarray   H&E image registered to metabolomics coordinates.
    """
    fn_he  = f'../data/hne_img_png/hne_{charge}_{batch}.png'
    fn_sp  = f'../data/hne_img_png/spmetabo_{charge}_{batch}.png'

    img_he = np.array(Image.open(fn_he).convert('L'))
    img_sp = np.array(Image.open(fn_sp).convert('L'))

    fixed   = sitk.GetImageFromArray(img_sp.astype(np.float32))
    moving  = sitk.GetImageFromArray(img_he.astype(np.float32))

    # Euler 2-D rigid registration: translation + rotation only
    registration = sitk.ImageRegistrationMethod()
    registration.SetMetricAsMattesMutualInformation(numberOfHistogramBins=50)
    registration.SetOptimizerAsGradientDescent(
        learningRate=1.0, numberOfIterations=100,
        convergenceMinimumValue=1e-6, convergenceWindowSize=10
    )
    registration.SetOptimizerScalesFromPhysicalShift()
    registration.SetInitialTransform(
        sitk.CenteredTransformInitializer(
            fixed, moving, sitk.Euler2DTransform(),
            sitk.CenteredTransformInitializerFilter.GEOMETRY
        )
    )
    registration.SetInterpolator(sitk.sitkLinear)
    if verbose:
        registration.AddCommand(sitk.sitkIterationEvent,
                                lambda: command_iteration(registration))

    final_transform = registration.Execute(fixed, moving)
    resampled = sitk.Resample(
        moving, fixed, final_transform, sitk.sitkLinear, 0.0,
        moving.GetPixelID()
    )
    a = sitk.GetArrayFromImage(resampled)
    if verbose:
        print(f"  Registration complete: Final metric = {registration.GetMetricValue():.6f}")
    return a


def create_img_bydim(a, M, N):
    """
    Embed image `a` (shape p×q×r) into a zero array of shape M×N×r.
    Used to create a mask image matching the H&E crop dimensions.
    """
    p, q, r = a.shape
    out = np.zeros((M, N, r), dtype=a.dtype)
    out[:min(p, M), :min(q, N), :] = a[:min(p, M), :min(q, N), :]
    return out


def bimask_close(batch, charge, iter=1, saveit=True, verbose=True):
    """
    Create a binary tissue mask from the H&E image using Otsu thresholding
    followed by morphological closing (to fill small holes in the tissue).

    Saved as a binary PNG for use in the annotation projection step.
    """
    fn = f'../data/hne_img_png/hne_{charge}_{batch}.png'
    if not os.path.isfile(fn):
        print(f"  [{batch}] H&E image not found; skipping.")
        return

    img_he  = cv2.imread(fn)
    img_gray = cv2.cvtColor(img_he, cv2.COLOR_BGR2GRAY)
    _, mask  = cv2.threshold(img_gray, 0, 255,
                              cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    kernel  = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (20, 20))
    closed  = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iter)

    if saveit:
        fn_out = f'../data/hne_img_png/bimask_{charge}_{batch}.png'
        cv2.imwrite(fn_out, closed)
        if verbose: print(f"  Saved binary mask: {fn_out}")


def qumask2png(batch, charge, verbose=True):
    """
    Combine QuPath-exported binary annotation masks for a given tissue section
    into a single multi-label PNG image.

    QuPath exports one PNG per annotation class; this function overlays them
    into one image with a label per annotation category (see dict_label).

    Saves the combined mask as a PNG for downstream projection.
    """
    fn_he = '../data/hne_img_png/hne_{}_{}.png'.format(charge, batch)
    if not os.path.isfile(fn_he):
        if verbose: print(f"  [{batch}] H&E image not found; skipping.")
        return

    img_he = cv2.imread(fn_he)
    M, N   = img_he.shape[:2]
    mask_combined = np.zeros((M, N), dtype=np.uint8)

    for label_name, label_val in dict_label.items():
        fn_mask = [a for a in fnlist_mask if label_name.replace(' ', '_') in a
                   and str(sid) in a]
        if len(fn_mask) == 0:
            continue
        mask_raw = cv2.imread(fn_mask[0], cv2.IMREAD_GRAYSCALE)
        mask_rs  = cv2.resize(mask_raw, (N, M), interpolation=cv2.INTER_NEAREST)
        mask_combined[mask_rs > 0] = label_val

    fn_out = f'../data/hne_img_png/qumask_{charge}_{batch}.png'
    cv2.imwrite(fn_out, mask_combined)
    if verbose: print(f"  Saved combined mask: {fn_out}")

# %%
# ── Example: process one slide ─────────────────────────────────────────────────
sid = '38828'    # H&E slide ID (matches SVS filename and metadata)
fsid = f'../data/heslides/{sid}.svs'

# Load whole-slide H&E image
img = svs2img(fsid)
print(f"Slide shape: {img.shape}")

# Preview at reduced resolution
plt.imshow(rescale(img, 0.1, anti_aliasing=False))
plt.title(f"Slide {sid} (10% resolution)")
plt.axis('off')
plt.show()

# %%
# Identify ion panel for this slide and load the corresponding metabolomics data
charge = meta_sid.query('slideid == @sid')['ions'].values[0]
adata  = adata_pos.copy() if charge == 'pos' else adata_neg.copy()
print(f"Slide {sid}: ion panel = {charge}")

# Find all tissue sections (batches) on this slide
df_sample_pos = findbatchid(sid, charge, meta_sid, metadb)

# Initialise crop index and metadata columns
df_sample_pos[['xmin', 'xmax', 'ymin', 'ymax']] = 0
df_sample_pos[['sid', 'ions']] = [sid, charge]
df_sample_pos

# %%
# ── Define crop coordinates for each tissue section ───────────────────────────
# Inspect the whole-slide image and manually identify the crop boundaries for
# each tissue section. Repeat for each batch/tissue.

batch = 'pid7_day1'

# Build a metabolomics reference image for this tissue section
template = adata2img(adata, batch, charge, scaled=False, resized=False,
                     saveit=True, verbose=True)
l_img = np.max(template.shape)   # reference size for H&E rescaling

# Set crop indices (adjust by inspecting img[xmin:xmax, ymin:ymax, :3] below)
xmin, xmax, ymin, ymax = 24000, 30000, 63000, 73000

# Verify crop visually
plt.imshow(img[xmin:xmax, ymin:ymax, :3])
plt.title(f"{batch} — H&E crop")
plt.axis('off')
plt.show()

# Store crop indices
df_sample_pos.loc[batch, ['xmin', 'xmax', 'ymin', 'ymax']] = [xmin, xmax, ymin, ymax]

# %%
# ── Crop and rescale H&E image, then align to metabolomics image ──────────────
# cutnscale: crop, resize, optionally erode+dilate for solid-shape alignment
# alignimgs: SimpleITK rigid registration (metabolomics → H&E coordinate space)

cutnscale(img, xmin, xmax, ymin, ymax, charge,
          erdl=False, k=70, resized=True, l_img=l_img,
          saveit=True, verbose=True)

a = alignimgs(batch, charge, verbose=True)
print(f"Aligned image shape: {a.shape}")

# %% [markdown]
# ---
# ## Batch Processing: Crop All Tissue Sections on a Slide
#
# After defining crop indices for all tissues on a slide (populating `df_sample_pos`),
# the following cells crop, scale, and process each section in batch.

# %%
# Remove placeholder rows not needed for this slide (edit as appropriate)
# df_sample_pos.drop(['pid9_day1', 'pid5_day60'], inplace=True)
df_sample_pos

# %%
# Crop H&E image for all tissues on all slides in df_sample_pos
for sid_loop in df_sample_pos.sid.unique():
    fn_sid = f'../data/heslides/{sid_loop}.svs'
    img_loop = pyvips.Image.new_from_file(fn_sid)
    print(f"Processing slide {sid_loop}")

    for i, row in df_sample_pos.query('sid == @sid_loop').iterrows():
        cutnscale(
            img_loop.numpy(),
            row.xmin, row.xmax, row.ymin, row.ymax,
            row.ions, erdl=False, resized=True, l_img=l_img,
            saveit=True, verbose=True
        )
        cutnscale(
            img_loop.numpy(),
            row.xmin, row.xmax, row.ymin, row.ymax,
            row.ions, erdl=True, k=70, resized=True, l_img=l_img,
            saveit=True, verbose=True
        )

# %% [markdown]
# ---
# ## Annotation Mask Projection
#
# QuPath-exported PNG masks (one per annotation class) are combined into a single
# multi-label mask image per tissue section. The label dictionary below maps each
# annotation class name to a numeric label used in downstream analysis.

# %%
# Annotation class → integer label mapping (must match QuPath class names)
dict_label = {
    'N - normal glandular': 1,
    'adipocytes':           2,
    'blood vessel':         3,
    'artifact':             4,
    'stroma':               5,
}

# Load all QuPath mask PNGs
fnlist_mask = glob('../data/masks/*png')
print(f"Found {len(fnlist_mask)} mask files.")

# Extra buffer to prevent mask–tissue misalignment at edges
d_extra = 1000

# %%
# Build binary tissue mask from H&E and combine QuPath annotation masks
for i, row in df_sample_pos.query('sid == @sid').iterrows():
    bimask_close(i, row.ions, iter=1, saveit=True, verbose=True)
    qumask2png(i, row.ions, verbose=True)
